# %% [markdown]
# # Import Libs

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import KMeans
import scipy.cluster.hierarchy as sch
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score
from mpl_toolkits.mplot3d import Axes3D
import plotly.express as px

import warnings
warnings.filterwarnings("ignore")

# %%
train_df = pd.read_csv("/kaggle/input/customer-segmentation-tutorial-in-python/Mall_Customers.csv")
train_df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %% [markdown]
# # EDA

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
train_df.nunique()
# Out:
# CustomerID                200
# Gender                      2
# Age                        51
# Annual Income (k$)         64
# Spending Score (1-100)     84
# dtype: int64

# %%
train_df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
train_df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %% [markdown]
# ## Elbow Method

# %%
train_df.rename(columns={'Annual Income (k$)': 'Income', 'Spending Score (1-100)': 'Score'}, inplace=True)
train_df["gender_numeric"] = train_df["Gender"].map({"Male":0 , "Female":1})

X = train_df[["Age","Income","Score"]]

wcss = []
for i in range (1,11):
    kmeans = KMeans(n_clusters=i , init="k-means++" , random_state=42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(10,6))
plt.plot(range(1,11) , wcss , marker="o" , linestyle="--")
plt.title("Elbow Method")
plt.xlabel("N_Cluster")
plt.ylabel("WCSS")
plt.show()

# %% [markdown]
# ## Dendogram

# %%
plt.figure(figsize=(15,6))
dendrogram = sch.dendrogram(sch.linkage(X , method="ward"))
plt.axhline(y=10 , color="r" , linestyle="--")
plt.title("Dendrogram")
plt.xlabel("Customer")
plt.ylabel("Eucledian Distance")
plt.show()

# %% [markdown]
# # Modelling(KMeans)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA(n_components = 3)
X_pca = pca.fit_transform(X_scaled)

kmeans = KMeans(n_clusters=6 , init="k-means++" , random_state=42)
train_df["Cluster"] = kmeans.fit_predict(X_pca)


plt.figure(figsize=(10,7))
sns.scatterplot(x=X_pca[:,0] , y=X_pca[:,1] , hue=train_df["Cluster"] , palette = "Set1" , s=100)
plt.title('5 Customer Segments with 4D Data (PCA Analysis)')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.legend(title='Cluster')
plt.show()

print("--- Average Feature Values ---")
display(train_df.groupby('Cluster')[['Age', 'Income', 'Score', 'gender_numeric']].mean())
# Out:
# --- Average Feature Values ---
#                Age     Income      Score  gender_numeric
# Cluster
# 0        56.333333  54.266667  49.066667        0.577778
# 1        32.692308  86.538462  82.128205        0.538462
# 2        25.560000  26.480000  76.240000        0.560000
# 3        26.125000  59.425000  44.450000        0.600000
# 4        44.000000  90.133333  17.933333        0.466667
# 5        45.523810  26.285714  19.380952        0.619048

# %% [markdown]
# # Result

# %%
score = silhouette_score(X_scaled , train_df["Cluster"])
print(f"---Silhouette Score: {score:.4f} ---")

fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(111 , projection = "3d")

colors = ["red" , "blue" , "green" , "cyan","magenta"]

for i in range(5):
    ax.scatter(train_df.loc[train_df["Cluster"] == i , "Age"] ,
               train_df.loc[train_df["Cluster"] == i , "Income"] ,
               train_df.loc[train_df["Cluster"] == i , "Score"] ,
               c=colors[i] ,s=100 , label = f"Cluster {i}" , alpha = 0.7
              )
# Out:
# ---Silhouette Score: 0.4311 ---

# %%
fig = px.scatter_3d(train_df, x='Age', y='Income', z='Score',
                    color='Cluster', 
                    title='Final Customer Segmentation',
                    labels={'Income': 'Annual Income (k$)', 'Score': 'Spending Score'},
                    opacity=0.8,
                    color_discrete_sequence=px.colors.qualitative.Vivid)

fig.show()

"""
print("--- Customer Profile ---")
final_analysis = train_df.groupby('Cluster').agg({
    'Age': 'mean',
    'Income': 'mean',
    'Score': 'mean',
    'Cluster': 'count'
}).rename(columns={'Cluster': 'Count'}).reset_index()

display(final_analysis)
"""
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
